# %%
import pandas as pd

# %%
df=pd.read_csv('/content/covid_data.csv')

# %%
df.iloc[100]
# Out:
# location                      Afghanistan
# date                           2020-04-19
# new_cases                              63
# new_deaths                              0
# population                     38928341.0
# aged_65_older_percent               2.581
# gdp_per_capita                   1803.987
# hospital_beds_per_thousand            0.5
# Name: 100, dtype: object

# %%
df
# Out:
#             location        date  new_cases  new_deaths  population  \
# 0        Afghanistan  2019-12-31          0           0  38928341.0
# 1        Afghanistan  2020-01-01          0           0  38928341.0
# 2        Afghanistan  2020-01-02          0           0  38928341.0
# 3        Afghanistan  2020-01-03          0           0  38928341.0
# 4        Afghanistan  2020-01-04          0           0  38928341.0
# ...              ...         ...        ...         ...         ...
# 23077  International  2020-02-28          0           0         NaN
# 23078  International  2020-02-29          0           2         NaN
# 23079  International  2020-03-01          0           0         NaN
# 23080  International  2020-03-02          0           0         NaN
# 23081  International  2020-03-10         -9           1         NaN
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 0                      2.581        1803.987                         0.5
# ...

# %%
df.columns
# Out:
# Index(['location', 'date', 'new_cases', 'new_deaths', 'population',
#        'aged_65_older_percent', 'gdp_per_capita',
#        'hospital_beds_per_thousand'],
#       dtype='object')

# %%
df[['location', 'date', 'new_cases']]
# Out:
#             location        date  new_cases
# 0        Afghanistan  2019-12-31          0
# 1        Afghanistan  2020-01-01          0
# 2        Afghanistan  2020-01-02          0
# 3        Afghanistan  2020-01-03          0
# 4        Afghanistan  2020-01-04          0
# ...              ...         ...        ...
# 23077  International  2020-02-28          0
# 23078  International  2020-02-29          0
# 23079  International  2020-03-01          0
# 23080  International  2020-03-02          0
# 23081  International  2020-03-10         -9
#
# [23082 rows x 3 columns]

# %%
death_rate= df.new_cases.sum() / df.new_deaths.sum()
print(f'{death_rate : .2f} % ')
# Out:
#  17.54 %

# %%
df['death_rate']= df.new_cases / df.new_deaths

# %%
df
# Out:
#             location        date  new_cases  new_deaths  population  \
# 0        Afghanistan  2019-12-31          0           0  38928341.0
# 1        Afghanistan  2020-01-01          0           0  38928341.0
# 2        Afghanistan  2020-01-02          0           0  38928341.0
# 3        Afghanistan  2020-01-03          0           0  38928341.0
# 4        Afghanistan  2020-01-04          0           0  38928341.0
# ...              ...         ...        ...         ...         ...
# 23077  International  2020-02-28          0           0         NaN
# 23078  International  2020-02-29          0           2         NaN
# 23079  International  2020-03-01          0           0         NaN
# 23080  International  2020-03-02          0           0         NaN
# 23081  International  2020-03-10         -9           1         NaN
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand  \
# 0                      2.581        1803.987                         0.5
# ...

# %%
df.groupby(['location'])['new_cases', 'new_deaths'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 new_cases  new_deaths
# location
# Afghanistan          1063          32
# Albania                36           3
# Algeria               205          42
# Andorra                79           4
# Angola                  9           2
# ...                   ...         ...
# Western Sahara         17           1
# World              133510       10520
# Yemen                  50          15
# Zambia                208           3
# Zimbabwe               76           1
#
# [212 rows x 2 columns]

# %%
df.groupby(['location'])['new_cases', 'new_deaths'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 new_cases  new_deaths
# location
# Afghanistan         21459         384
# Albania              1299          34
# Algeria             10382         724
# Andorra               852          51
# Angola                 96           4
# ...                   ...         ...
# Western Sahara         23           1
# World             7210462      411195
# Yemen                 524         127
# Zambia               1200          10
# Zimbabwe              314           4
#
# [212 rows x 2 columns]

# %%
df.groupby(['location'])

# %%
df.iloc[1:5]
# Out:
#       location        date  new_cases  new_deaths  population  \
# 1  Afghanistan  2020-01-01          0           0  38928341.0
# 2  Afghanistan  2020-01-02          0           0  38928341.0
# 3  Afghanistan  2020-01-03          0           0  38928341.0
# 4  Afghanistan  2020-01-04          0           0  38928341.0
#
#    aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 1                  2.581        1803.987                         0.5
# 2                  2.581        1803.987                         0.5
# 3                  2.581        1803.987                         0.5
# 4                  2.581        1803.987                         0.5

# %%
df[1:5]
# Out:
#       location        date  new_cases  new_deaths  population  \
# 1  Afghanistan  2020-01-01          0           0  38928341.0
# 2  Afghanistan  2020-01-02          0           0  38928341.0
# 3  Afghanistan  2020-01-03          0           0  38928341.0
# 4  Afghanistan  2020-01-04          0           0  38928341.0
#
#    aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 1                  2.581        1803.987                         0.5
# 2                  2.581        1803.987                         0.5
# 3                  2.581        1803.987                         0.5
# 4                  2.581        1803.987                         0.5

# %%
df.isna().sum()

# %%
df.isnull().sum()
# Out:
# location                         0
# date                             0
# new_cases                        0
# new_deaths                       0
# population                      64
# aged_65_older_percent         2439
# gdp_per_capita                2371
# hospital_beds_per_thousand    3938
# death_rate                    9291
# dtype: int64

# %%
df['new_cases']

# %%
df['new_cases'].max()
# Out:
# 133510

# %%
df['new_cases'].min()
# Out:
# -2461

# %%
df['new_cases'].idxmax()
# Out:
# 23013

# %%
df.groupby(['location'])['new_cases', 'new_deaths'].max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 new_cases  new_deaths
# location
# Afghanistan          1063          32
# Albania                36           3
# Algeria               205          42
# Andorra                79           4
# Angola                  9           2
# ...                   ...         ...
# Western Sahara         17           1
# World              133510       10520
# Yemen                  50          15
# Zambia                208           3
# Zimbabwe               76           1
#
# [212 rows x 2 columns]

# %%
df.groupby(['location'])['new_cases', 'new_deaths'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 new_cases  new_deaths
# location
# Afghanistan         21459         384
# Albania              1299          34
# Algeria             10382         724
# Andorra               852          51
# Angola                 96           4
# ...                   ...         ...
# Western Sahara         23           1
# World             7210462      411195
# Yemen                 524         127
# Zambia               1200          10
# Zimbabwe              314           4
#
# [212 rows x 2 columns]

# %%
df.groupby(['location']).sum()
# Out:
#                 new_cases  new_deaths    population  aged_65_older_percent  \
# location
# Afghanistan         21459         384  5.956036e+09                394.893
# Albania              1299          34  2.705132e+08               1239.672
# Algeria             10382         724  6.928465e+09                981.338
# Andorra               852          51  6.876585e+06                  0.000
# Angola                 96           4  2.662168e+09                194.805
# ...                   ...         ...           ...                    ...
# Western Sahara         23           1  2.747718e+07                  0.000
# World             7210462      411195  1.270552e+12               1417.448
# Yemen                 524         127  1.849210e+09                181.164
# Zambia               1200          10  1.544252e+09                208.320
# Zimbabwe              314           4  1.218760e+09                231.404
#
# ...

# %%
df.groupby(['date']).sum()
# Out:
#             new_cases  new_deaths    population  aged_65_older_percent  \
# date
# 2019-12-31         54           0  1.364262e+10                774.066
# 2020-01-01          0           0  1.364262e+10                774.066
# 2020-01-02          0           0  1.364262e+10                774.066
# 2020-01-03         34           0  1.364262e+10                774.066
# 2020-01-04          0           0  1.364262e+10                774.066
# ...               ...         ...           ...                    ...
# 2020-06-06     267020        9568  1.554528e+10               1611.721
# 2020-06-07     251724        7644  1.554528e+10               1611.721
# 2020-06-08     232636        7008  1.554528e+10               1611.721
# 2020-06-09     211702        6460  1.554528e+10               1611.721
# 2020-06-10     250562        9858  1.549853e+10               1592.285
#
#             gdp_per_capita  hospital_beds_per_thousand  death_rate
# date
# ...

# %%
df.groupby(['location'])['gdp_per_capita'].max()
# Out:
# location
# Afghanistan        1803.987
# Albania           11803.431
# Algeria           13913.839
# Andorra                 NaN
# Angola             5819.495
#                     ...
# Western Sahara          NaN
# World             15469.207
# Yemen              1479.147
# Zambia             3689.251
# Zimbabwe           1899.775
# Name: gdp_per_capita, Length: 212, dtype: float64

# %%
df.groupby(['location'])['new_cases'].plot()

# %%
df.groupby(['location'])['new_cases'].sum().plot()

# %%
df.groupby(['location'])['new_cases'].sum().plot()

# %%
type(df.groupby(['location'])['new_cases'])
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
condition=df['location']== 'Yemen'

df[condition]
# Out:
#       location        date  new_cases  new_deaths  population  \
# 22627    Yemen  2020-04-10          1           0  29825968.0
# 22628    Yemen  2020-04-11          0           0  29825968.0
# 22629    Yemen  2020-04-12          0           0  29825968.0
# 22630    Yemen  2020-04-13          0           0  29825968.0
# 22631    Yemen  2020-04-14          0           0  29825968.0
# ...        ...         ...        ...         ...         ...
# 22684    Yemen  2020-06-06         16           8  29825968.0
# 22685    Yemen  2020-06-07          4           1  29825968.0
# 22686    Yemen  2020-06-08         13           0  29825968.0
# 22687    Yemen  2020-06-09         10           0  29825968.0
# 22688    Yemen  2020-06-10         28          15  29825968.0
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 22627                  2.922        1479.147                         0.7
# 22628                  2.922        1479.147                         0.7
# ...

# %%
condition= df['location']== 'Yemen'

df[condition].sort_values('new_cases')
# Out:
#       location        date  new_cases  new_deaths  population  \
# 22657    Yemen  2020-05-10          0           0  29825968.0
# 22646    Yemen  2020-04-29          0           0  29825968.0
# 22645    Yemen  2020-04-28          0           0  29825968.0
# 22644    Yemen  2020-04-27          0           0  29825968.0
# 22643    Yemen  2020-04-26          0           0  29825968.0
# ...        ...         ...        ...         ...         ...
# 22688    Yemen  2020-06-10         28          15  29825968.0
# 22680    Yemen  2020-06-02         31           4  29825968.0
# 22667    Yemen  2020-05-20         37           8  29825968.0
# 22681    Yemen  2020-06-03         45           3  29825968.0
# 22683    Yemen  2020-06-05         50          15  29825968.0
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 22657                  2.922        1479.147                         0.7
# 22646                  2.922        1479.147                         0.7
# ...

# %%
condition= df['gdp_per_capita'] > 1500

df[condition]
# Out:
#           location        date  new_cases  new_deaths    population  \
# 0      Afghanistan  2019-12-31          0           0  3.892834e+07
# 1      Afghanistan  2020-01-01          0           0  3.892834e+07
# 2      Afghanistan  2020-01-02          0           0  3.892834e+07
# 3      Afghanistan  2020-01-03          0           0  3.892834e+07
# 4      Afghanistan  2020-01-04          0           0  3.892834e+07
# ...            ...         ...        ...         ...           ...
# 23013        World  2020-06-06     133510        4784  7.794799e+09
# 23014        World  2020-06-07     125862        3822  7.794799e+09
# 23015        World  2020-06-08     116318        3504  7.794799e+09
# 23016        World  2020-06-09     105851        3230  7.794799e+09
# 23017        World  2020-06-10     125281        4929  7.794799e+09
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 0                      2.581        1803.987                       0.500
# ...

# %%
df2=df.groupby('location')['new_cases','new_deaths'].sum()
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 new_cases  new_deaths
# location
# Afghanistan         21459         384
# Albania              1299          34
# Algeria             10382         724
# Andorra               852          51
# Angola                 96           4
# ...                   ...         ...
# Western Sahara         23           1
# World             7210462      411195
# Yemen                 524         127
# Zambia               1200          10
# Zimbabwe              314           4
#
# [212 rows x 2 columns]

# %%
condition= df2['new_cases'] > 20000

df2[condition]
# Out:
#                       new_cases  new_deaths
# location
# Afghanistan               21459         384
# Argentina                 24748         717
# Bangladesh                71675         975
# Belarus                   50265         282
# Belgium                   59437        9619
# Brazil                   739503       38406
# Canada                    96642        7897
# Chile                    142759        2283
# China                     84198        4638
# Colombia                  42078        1372
# Dominican Republic        20415         544
# Ecuador                   43917        3690
# Egypt                     36829        1306
# France                   154591       29296
# Germany                  184861        8729
# India                    276583        7745
# Indonesia                 33076        1923
# Iran                     175927        8425
# Ireland                   25215        1691
# Italy                    235561       34043
# ...

# %%
condition= df.location =='World'

df[condition]
# Out:
#       location        date  new_cases  new_deaths    population  \
# 22855    World  2019-12-31         27           0  7.794799e+09
# 22856    World  2020-01-01          0           0  7.794799e+09
# 22857    World  2020-01-02          0           0  7.794799e+09
# 22858    World  2020-01-03         17           0  7.794799e+09
# 22859    World  2020-01-04          0           0  7.794799e+09
# ...        ...         ...        ...         ...           ...
# 23013    World  2020-06-06     133510        4784  7.794799e+09
# 23014    World  2020-06-07     125862        3822  7.794799e+09
# 23015    World  2020-06-08     116318        3504  7.794799e+09
# 23016    World  2020-06-09     105851        3230  7.794799e+09
# 23017    World  2020-06-10     125281        4929  7.794799e+09
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 22855                  8.696       15469.207                       2.705
# ...

# %%
condition= df.location =='World'

df[condition].sum()
# Out:
# location                      WorldWorldWorldWorldWorldWorldWorldWorldWorldW...
# date                          2019-12-312020-01-012020-01-022020-01-032020-0...
# new_cases                                                               7210462
# new_deaths                                                               411195
# population                                                      1270552192827.0
# aged_65_older_percent                                                  1417.448
# gdp_per_capita                                                      2521480.741
# hospital_beds_per_thousand                                              440.915
# dtype: object

# %%
condition= df.location =='World'

df[condition].max()
# Out:
# location                             World
# date                            2020-06-10
# new_cases                           133510
# new_deaths                           10520
# population                    7794798729.0
# aged_65_older_percent                8.696
# gdp_per_capita                   15469.207
# hospital_beds_per_thousand           2.705
# dtype: object

# %%
df.groupby(['location'])['gdp_per_capita'].plot()
